# %% [markdown]
# # CUSTOMER RETENTION PROJECT

# %%
#import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Load Customer retention dataset
cust=pd.read_csv("customer_retention_dataset.csv")
cust
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
cust.shape
# Out:
# (269, 71)

# %%
cust.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
cust.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
#checking if null values are present
cust.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
cust.nunique()
# Out:
# 1Gender of respondent                                                    2
# 2 How old are you?                                                       5
# 3 Which city do you shop online from?                                   11
# 4 What is the Pin Code of where you shop online from?                   39
# 5 Since How Long You are Shopping Online ?                               5
#                                                                         ..
# Longer delivery period                                                   6
# Change in website/Application design                                     7
# Frequent disruption when moving from one page to another                 8
# Website is as efficient as before                                        8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %%
#Removing numbers from column names
from string import digits

cust.columns=cust.columns.str.replace('\t','')

remove_digits=str.maketrans('', '', digits)
cust.columns=cust.columns.str.translate(remove_digits)

cust.columns=cust.columns.str.strip()

# %%
cust.columns
# Out:
# Index(['Gender of respondent', 'How old are you?',
#        'Which city do you shop online from?',
#        'What is the Pin Code of where you shop online from?',
#        'Since How Long You are Shopping Online ?',
#        'How many times you have made an online purchase in the past  year?',
#        'How do you access the internet while shopping on-line?',
#        'Which device do you use to access the online shopping?',
#        'What is the screen size of your mobile device?',
#        'What is the operating system (OS) of your device?',
#        'What browser do you run on your device to access the website?',
#        'Which channel did you follow to arrive at your favorite online store for the first time?',
#        'After first visit, how do you reach the online retail store?',
#        'How much time do you explore the e- retail store before making a purchase decision?',
#        'What is your preferred payment Option?',
# ...

# %% [markdown]
# # EDA:

# %% [markdown]
# # Visualization

# %%
sns.countplot(cust["Gender of respondent"])
print(cust['Gender of respondent'].value_counts())
# Out:
# Female    181
# Male       88
# Name: Gender of respondent, dtype: int64

# %% [markdown]
# Females shop from online more than males.

# %%
sns.countplot(cust["How old are you?"])
print(cust['How old are you?'].value_counts())
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: How old are you?, dtype: int64

# %% [markdown]
# Customers who shop more has the age range from 31-40 years.

# %%
sns.countplot(cust["Which city do you shop online from?"])
print(cust['Which city do you shop online from?'].value_counts())
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: Which city do you shop online from?, dtype: int64

# %% [markdown]
# Customers from Delhi shop from online more than other cities.

# %%
sns.countplot(cust["Since How Long You are Shopping Online ?"])
print(cust['Since How Long You are Shopping Online ?'].value_counts())
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: Since How Long You are Shopping Online ?, dtype: int64

# %% [markdown]
# Most of the customers are shopping online since more than 4 years.

# %%
sns.countplot(cust["How many times you have made an online purchase in the past  year?"])
print(cust['How many times you have made an online purchase in the past  year?'].value_counts())
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: How many times you have made an online purchase in the past  year?, dtype: int64

# %% [markdown]
# Most of the customers have shopped less than 10 times in a past year and few customers have shopped 42 times and above.

# %%
sns.countplot(cust["How do you access the internet while shopping on-line?"])
print(cust['How do you access the internet while shopping on-line?'].value_counts())
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# Mostly the customers had mobile internet access while shopping online.

# %%
sns.countplot(cust["Which device do you use to access the online shopping?"])
print(cust['Which device do you use to access the online shopping?'].value_counts())
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: Which device do you use to access the online shopping?, dtype: int64

# %% [markdown]
# Online shopping was mostly done using smartphones.

# %%
sns.countplot(cust["What is the screen size of your mobile device?"])
print(cust['What is the screen size of your mobile device?'].value_counts())
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: What is the screen size of your mobile device?, dtype: int64

# %% [markdown]
# Most of the customers use device for online shopping with screen sizem above 5.5 inches

# %%
sns.countplot(cust["What is the operating system (OS) of your device?"])
print(cust['What is the operating system (OS) of your device?'].value_counts())
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: What is the operating system (OS) of your device?, dtype: int64

# %% [markdown]
# Windows is the operating system often used while online shopping.

# %%
sns.countplot(cust["What browser do you run on your device to access the website?"])
print(cust['What browser do you run on your device to access the website?'].value_counts())
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: What browser do you run on your device to access the website?, dtype: int64

# %% [markdown]
# Google Chrome browser is mostly used by the online customers.

# %%
sns.countplot(cust["Which channel did you follow to arrive at your favorite online store for the first time?"])
print(cust['Which channel did you follow to arrive at your favorite online store for the first time?'].value_counts())
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: Which channel did you follow to arrive at your favorite online store for the first time?, dtype: int64

# %% [markdown]
# Search engine is the most often used channel to arrive the online store for the first time.

# %%
sns.countplot(cust["After first visit, how do you reach the online retail store?"])
print(cust['After first visit, how do you reach the online retail store?'].value_counts())
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: After first visit, how do you reach the online retail store?, dtype: int64

# %% [markdown]
# Search engine and application is most used to visit the online store.

# %%
sns.countplot(cust["How much time do you explore the e- retail store before making a purchase decision?"])
print(cust['How much time do you explore the e- retail store before making a purchase decision?'].value_counts())
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: How much time do you explore the e- retail store before making a purchase decision?, dtype: int64

# %% [markdown]
# Most of the customers take more than 15 minutes to explore the store before making a purchase decision.

# %%
sns.countplot(cust["What is your preferred payment Option?"])
print(cust['What is your preferred payment Option?'].value_counts())
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: What is your preferred payment Option?, dtype: int64

# %% [markdown]
# Credit/Debit card is the most preferred payment option.

# %%
sns.countplot(cust["How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?"])
print(cust['How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'].value_counts())
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?, dtype: int64

# %% [markdown]
# Most of the customers, sometimes abandon product at the shopping cart.

# %%
sns.countplot(cust["Why did you abandon the “Bag”, “Shopping Cart”?"])
print(cust['Why did you abandon the “Bag”, “Shopping Cart”?'].value_counts())
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: Why did you abandon the “Bag”, “Shopping Cart”?, dtype: int64

# %% [markdown]
# The reason for most of them to abandon the product at the shopping cart is because of the better alternative offer.

# %%
sns.countplot(cust["The content on the website must be easy to read and understand"])
print(cust['The content on the website must be easy to read and understand'].value_counts())
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: The content on the website must be easy to read and understand, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that the content on the website must be easy to read and understand.

# %%
sns.countplot(cust["Information on similar product to the one highlighted  is important for product comparison"])
print(cust['Information on similar product to the one highlighted  is important for product comparison'].value_counts())
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that information on similar product to the one highlighted  is important for product comparison.

# %%
sns.countplot(cust["Complete information on listed seller and product being offered is important for purchase decision."])
print(cust['Complete information on listed seller and product being offered is important for purchase decision.'].value_counts())
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %% [markdown]
# Most of the customers agree that complete information on listed seller and product being offered is important for purchase decision.

# %%
sns.countplot(cust["All relevant information on listed products must be stated clearly"])
print(cust['All relevant information on listed products must be stated clearly'].value_counts())
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: All relevant information on listed products must be stated clearly, dtype: int64

# %% [markdown]
# Most of the customers agree that all relevant information on listed products must be stated clearly

# %%
sns.countplot(cust["Ease of navigation in website"])
print(cust['Ease of navigation in website'].value_counts())
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: Ease of navigation in website, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that there must be ease of navigation in website.

# %%
sns.countplot(cust["Loading and processing speed"])
print(cust['Loading and processing speed'].value_counts())
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Indifferent (3)           12
# Strongly disagree (1)     12
# Name: Loading and processing speed, dtype: int64

# %% [markdown]
# Most of the customers strongly agree to have good loading and processing speeed.

# %%
sns.countplot(cust["User friendly Interface of the website"])
print(cust['User friendly Interface of the website'].value_counts())
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: User friendly Interface of the website, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that there must be good User friendly Interface of the website

# %%
sns.countplot(cust["Convenient Payment methods"])
print(cust['Convenient Payment methods'].value_counts())
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: Convenient Payment methods, dtype: int64

# %% [markdown]
# Most of the customers strongly agree to have convinient payment methods.

# %%
sns.countplot(cust["Trust that the online retail store will fulfill its part of the transaction at the stipulated time"])
print(cust['Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts())
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %% [markdown]
# Trust that the online retail store will fulfill its part of the transaction at the stipulated time is strongly agreed by most of the online customers.

# %%
sns.countplot(cust["Empathy (readiness to assist with queries) towards the customers"])
print(cust['Empathy (readiness to assist with queries) towards the customers'].value_counts())
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %% [markdown]
# Empathy towards the customers is strongly agreed by most customers.

# %%
sns.countplot(cust["Being able to guarantee the privacy of the customer"])
print(cust['Being able to guarantee the privacy of the customer'].value_counts())
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: Being able to guarantee the privacy of the customer, dtype: int64

# %% [markdown]
# Being able to guarantee the privacy of the customer is strongly agreed by most customers.

# %%
sns.countplot(cust["Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)"])
print(cust['Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts())
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %% [markdown]
# Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc. should be provided is strongly agreed by most of the customers.

# %%
sns.countplot(cust["Online shopping gives monetary benefit and discounts"])
print(cust['Online shopping gives monetary benefit and discounts'].value_counts())
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: Online shopping gives monetary benefit and discounts, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that there must be monetory benefit and discounts.

# %%
sns.countplot(cust["Enjoyment is derived from shopping online"])
print(cust['Enjoyment is derived from shopping online'].value_counts())
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: Enjoyment is derived from shopping online, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that enjoyment is derived from shopping online.

# %%
sns.countplot(cust["Shopping online is convenient and flexible"])
print(cust['Shopping online is convenient and flexible'].value_counts())
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: Shopping online is convenient and flexible, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that shopping online is convenient and flexible

# %%
sns.countplot(cust["Return and replacement policy of the e-tailer is important for purchase decision"])
print(cust['Return and replacement policy of the e-tailer is important for purchase decision'].value_counts())
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that return and replacement policy of the e-tailer is important for purchase decision

# %%
sns.countplot(cust["Gaining access to loyalty programs is a benefit of shopping online"])
print(cust['Gaining access to loyalty programs is a benefit of shopping online'].value_counts())
# Out:
# Strongly agree (5)       115
# indifferent (3)           64
# Agree (4)                 64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %% [markdown]
# Most of the customers strongly agree for gaining access to loyalty programs is a benefit of shopping online

# %%
sns.countplot(cust["Displaying quality Information on the website improves satisfaction of customers"])
print(cust['Displaying quality Information on the website improves satisfaction of customers'].value_counts())
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that displaying quality Information on the website improves satisfaction of customers.

# %%
sns.countplot(cust["User derive satisfaction while shopping on a good quality website or application"])
print(cust['User derive satisfaction while shopping on a good quality website or application'].value_counts())
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that User derive satisfaction while shopping on a good quality website or application.

# %%
sns.countplot(cust["Net Benefit derived from shopping online can lead to users satisfaction"])
print(cust['Net Benefit derived from shopping online can lead to users satisfaction'].value_counts())
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that net Benefit derived from shopping online can lead to users satisfaction.

# %%
sns.countplot(cust["User satisfaction cannot exist without trust"])
print(cust['User satisfaction cannot exist without trust'].value_counts())
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: User satisfaction cannot exist without trust, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that user satisfaction cannot exist without trust.

# %%
sns.countplot(cust["Offering a wide variety of listed product in several category"])
print(cust['Offering a wide variety of listed product in several category'].value_counts())
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: Offering a wide variety of listed product in several category, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that there must be wide variety of listed product in several category.

# %%
sns.countplot(cust["Provision of complete and relevant product information"])
print(cust['Provision of complete and relevant product information'].value_counts())
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: Provision of complete and relevant product information, dtype: int64

# %% [markdown]
# Most of the customers strongly agree that there must be Provision of complete and relevant product information.

# %%
sns.countplot(cust["Monetary savings"])
print(cust['Monetary savings'].value_counts())
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: Monetary savings, dtype: int64

# %% [markdown]
# Most of the customers strongly agree on monetary savings.

# %%
sns.countplot(cust["The Convenience of patronizing the online retailer"])
print(cust['The Convenience of patronizing the online retailer'].value_counts())
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: The Convenience of patronizing the online retailer, dtype: int64

# %% [markdown]
# Most of the customers agree in the Convenience of patronizing the online retailer.

# %%
sns.countplot(cust["Shopping on the website gives you the sense of adventure"])
print(cust['Shopping on the website gives you the sense of adventure'].value_counts())
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: Shopping on the website gives you the sense of adventure, dtype: int64

# %% [markdown]
# Most of the customers agree that Shopping on the website gives you the sense of adventure.

# %%
sns.countplot(cust["Shopping on your preferred e-tailer enhances your social status"])
print(cust['Shopping on your preferred e-tailer enhances your social status'].value_counts())
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %% [markdown]
# Most of the customers have indifferent opininon that Shopping on your preferred e-tailer enhances your social status.

# %%
sns.countplot(cust["You feel gratification shopping on your favorite e-tailer"])
print(cust['You feel gratification shopping on your favorite e-tailer'].value_counts())
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: You feel gratification shopping on your favorite e-tailer, dtype: int64

# %% [markdown]
# Most of the customers have indifferent opinion that You feel gratification shopping on your favorite e-tailer.

# %%
sns.countplot(cust["Shopping on the website helps you fulfill certain roles"])
print(cust['Shopping on the website helps you fulfill certain roles'].value_counts())
# Out:
# indifferent (3)          88
# Agree (4)                88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: Shopping on the website helps you fulfill certain roles, dtype: int64

# %% [markdown]
# Most of the customers agree that Shopping on the website helps you fulfill certain roles.

# %%
sns.countplot(cust["Getting value for money spent"])
print(cust['Getting value for money spent'].value_counts())
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: Getting value for money spent, dtype: int64

# %% [markdown]
# Most of the customers agree in getting value for money spent.

# %%
sns.countplot(cust["From the following, tick any (or all) of the online retailers you have shopped from;"])
print(cust['From the following, tick any (or all) of the online retailers you have shopped from;'].value_counts())
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;, dtype: int64

# %% [markdown]
# 82 among 269 customers have shopped from Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com.

# %%
sns.countplot(cust["Easy to use website or application"])
print(cust['Easy to use website or application'].value_counts())
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com                                         44
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %% [markdown]
# Most of the customers find Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com esdy to use website or application.

# %%
sns.countplot(cust["Visual appealing web-page layout"])
print(cust['Visual appealing web-page layout'].value_counts())
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Myntra.com                                           15
# Myntra.com                                                      15
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual appealing web-page layout, dtype: int64

# %% [markdown]
# Most of the customers felt that Amazon.in, Flipkart.com has visual appealing web-page layout.

# %%
sns.countplot(cust["Wild variety of product on offer"])
print(cust['Wild variety of product on offer'].value_counts())
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Myntra.com                                            15
# Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64

# %% [markdown]
# Most of the customers agree that Amazon.in, Flipkart.com has wild variety of product on offer.

# %%
sns.countplot(cust["Complete, relevant description information of products"])
print(cust['Complete, relevant description information of products'].value_counts())
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64

# %% [markdown]
# Most of the customers feels that Amazon.in, Flipkart.com  provides complete, relevant description information of products.

# %%
sns.countplot(cust["Fast loading website speed of website and application"])
print(cust['Fast loading website speed of website and application'].value_counts())
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %% [markdown]
# Most of the customers finds that Amazon.in has fast loading website speed of website and application.

# %%
sns.countplot(cust["Reliability of the website or application"])
print(cust['Reliability of the website or application'].value_counts())
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %% [markdown]
# Most of the customers feels that Amazon.in has reliability of the website or application.

# %%
sns.countplot(cust["Quickness to complete purchase"])
print(cust['Quickness to complete purchase'].value_counts())
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Flipkart.com                                                 15
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %% [markdown]
# Most of the customers agree that Amazon.com has quickness to complete purchase.

# %%
sns.countplot(cust["Availability of several payment options"])
print(cust['Availability of several payment options'].value_counts())
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64

# %% [markdown]
# Most of the customers agrees that Amazon.in, Flipkart.com has availability of several payment options.

# %%
sns.countplot(cust["Speedy order delivery"])
print(cust['Speedy order delivery'].value_counts())
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com                               15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery, dtype: int64

# %% [markdown]
# Amazon.in has speedy order delivery.

# %%
sns.countplot(cust["Privacy of customers’ information"])
print(cust['Privacy of customers’ information'].value_counts())
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Amazon.in, Paytm.com                                            15
# Myntra.com                                                      15
# Flipkart.com                                                    15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64

# %% [markdown]
# Amazon.in has privacy of customers information.

# %%
sns.countplot(cust["Security of customer financial information"])
print(cust['Security of customer financial information'].value_counts())
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Paytm.com                                                       15
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64

# %% [markdown]
# Most of the customers finds that Amazon.in has security of customer financial information.

# %%
sns.countplot(cust["Perceived Trustworthiness"])
print(cust['Perceived Trustworthiness'].value_counts())
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %% [markdown]
# Most of the customers agree that Amazon.in has Perceived Trustworthiness.

# %%
sns.countplot(cust["Presence of online assistance through multi-channel"])
print(cust['Presence of online assistance through multi-channel'].value_counts())
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %% [markdown]
# Most of the customers agree that Amazon.in, Flipkart.com, Myntra.com, Snapdeal has presence of online assistance through multi-channel.

# %%
sns.countplot(cust["Longer time to get logged in (promotion, sales period)"])
print(cust['Longer time to get logged in (promotion, sales period)'].value_counts())
# Out:
# Amazon.in                                57
# Paytm.com                                38
# Amazon.in, Flipkart.com                  38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %% [markdown]
# Most of the customers find that Amazon.in takes longer time to get logged in (promotion, sales period).

# %%
sns.countplot(cust["Longer time in displaying graphics and photos (promotion, sales period)"])
print(cust['Longer time in displaying graphics and photos (promotion, sales period)'].value_counts())
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %% [markdown]
# Most of the customers agree that Amazon.in, Flipkart.com takes longer time in displaying graphics and photos (promotion, sales period).

# %%
sns.countplot(cust["Late declaration of price (promotion, sales period)"])
print(cust['Late declaration of price (promotion, sales period)'].value_counts())
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Amazon.in                  38
# Flipkart.com               38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %% [markdown]
#  Most of the customers agree that Myntra.com gives late declaration of price (promotion, sales period).

# %%
sns.countplot(cust["Longer page loading time (promotion, sales period)"])
print(cust['Longer page loading time (promotion, sales period)'].value_counts())
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %% [markdown]
# Most of the customers finds that Myntra.com takes longer page loading time (promotion, sales period).

# %%
sns.countplot(cust["Limited mode of payment on most products (promotion, sales period)"])
print(cust['Limited mode of payment on most products (promotion, sales period)'].value_counts())
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %% [markdown]
# Most of the customers agree that Snapdeal.com has limited mode of payment on most products.

# %%
sns.countplot(cust["Longer delivery period"])
print(cust['Longer delivery period'].value_counts())
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Myntra.com                 26
# Paytm.com, Snapdeal.com    26
# Name: Longer delivery period, dtype: int64

# %% [markdown]
# Most of the customers take longer delivery period.

# %%
sns.countplot(cust["Change in website/Application design"])
print(cust['Change in website/Application design'].value_counts())
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64

# %% [markdown]
# Most of the customers feels that Amazon.in should change in website/Application design.

# %%
sns.countplot(cust["Frequent disruption when moving from one page to another"])
print(cust['Frequent disruption when moving from one page to another'].value_counts())
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %% [markdown]
# Most of the customers feels that there is frequent disruption when moving from one page to another in Amazon.in.

# %%
sns.countplot(cust["Website is as efficient as before"])
print(cust['Website is as efficient as before'].value_counts())
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64

# %% [markdown]
# Most of the customers agree that Amazon.in website is as efficient as before.

# %%
sns.countplot(cust["Which of the Indian online retailer would you recommend to a friend?"])
print(cust['Which of the Indian online retailer would you recommend to a friend?'].value_counts())
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %% [markdown]
# Amazon.in is the most recommended by most of the customers.

# %%
cust.isnull().sum().any()
# Out:
# False

# %% [markdown]
# # Label Encoding:

# %%
from sklearn.preprocessing import LabelEncoder

cust_en=pd.DataFrame()
le=LabelEncoder()
for column in cust.columns:
    cust_en[column]=le.fit_transform(cust[column])
cust_en
# Out:
#      Gender of respondent  How old are you?  \
# 0                       1                 1
# 1                       0                 0
# 2                       0                 0
# 3                       1                 0
# 4                       0                 0
# ..                    ...               ...
# 264                     0                 0
# 265                     0                 1
# 266                     0                 2
# 267                     0                 4
# 268                     0                 2
#
#      Which city do you shop online from?  \
# 0                                      2
# 1                                      2
# 2                                      4
# 3                                      6
# 4                                      0
# ..                                   ...
# 264                                   10
# 265                                    3
# 266                                    0
# ...

# %%
cust_en.dtypes
# Out:
# Gender of respondent                                                    int32
# How old are you?                                                        int32
# Which city do you shop online from?                                     int32
# What is the Pin Code of where you shop online from?                     int64
# Since How Long You are Shopping Online ?                                int32
#                                                                         ...
# Longer delivery period                                                  int32
# Change in website/Application design                                    int32
# Frequent disruption when moving from one page to another                int32
# Website is as efficient as before                                       int32
# Which of the Indian online retailer would you recommend to a friend?    int32
# Length: 71, dtype: object

# %% [markdown]
# # Correlation:

# %%
cor=cust_en.corr()
cor
# Out:
#                                                     Gender of respondent  \
# Gender of respondent                                            1.000000
# How old are you?                                                0.046169
# Which city do you shop online from?                             0.080912
# What is the Pin Code of where you shop online f...             -0.289628
# Since How Long You are Shopping Online ?                       -0.057096
# ...                                                                  ...
# Longer delivery period                                          0.060838
# Change in website/Application design                           -0.164818
# Frequent disruption when moving from one page t...             -0.256638
# Website is as efficient as before                               0.055663
# Which of the Indian online retailer would you r...             -0.003372
#
#                                                     How old are you?  \
# ...

# %% [markdown]
# Correlation using heatmap:

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(cor.corr(), annot=True, linewidth=1, linecolor="black", fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
cor['Which of the Indian online retailer would you recommend to a friend?']
# Out:
# Gender of respondent                                                   -0.003372
# How old are you?                                                       -0.135263
# Which city do you shop online from?                                    -0.142123
# What is the Pin Code of where you shop online from?                    -0.097320
# Since How Long You are Shopping Online ?                                0.136106
#                                                                           ...
# Longer delivery period                                                  0.428419
# Change in website/Application design                                    0.423877
# Frequent disruption when moving from one page to another                0.122953
# Website is as efficient as before                                       0.252154
# Which of the Indian online retailer would you recommend to a friend?    1.000000
# ...

# %% [markdown]
# # Describe of dataset:

# %%
cust_en.describe()
# Out:
#        Gender of respondent  How old are you?  \
# count            269.000000        269.000000
# mean               0.327138          1.330855
# std                0.470042          1.183774
# min                0.000000          0.000000
# 25%                0.000000          0.000000
# 50%                0.000000          1.000000
# 75%                1.000000          2.000000
# max                1.000000          4.000000
#
#        Which city do you shop online from?  \
# count                           269.000000
# mean                              4.494424
# std                               3.187687
# min                               0.000000
# 25%                               2.000000
# 50%                               4.000000
# 75%                               7.000000
# max                              10.000000
#
#        What is the Pin Code of where you shop online from?  \
# count                                         269.000000
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(cust_en.describe()[:].transpose(),2), linewidth=2, annot=True, fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variable Summary")
plt.show()

# %% [markdown]
# From the above plotting we are determining mean,standard deviation, maximum and minimum value of each column.

# %%
cust_en.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                     --------------  -----
#  0   Gender of respondent                                                                                       269 non-null    int32
#  1   How old are you?                                                                                           269 non-null    int32
#  2   Which city do you shop online from?                                                                        269 non-null    int32
#  3   What is the Pin Code of where you shop online from?                                                        269 non-null    int64
# ...

# %% [markdown]
# # Data Cleaning:

# %%
cust=cust_en.drop(["Gender of respondent","How old are you?"],axis=1)

# %%
cust
# Out:
#      Which city do you shop online from?  \
# 0                                      2
# 1                                      2
# 2                                      4
# 3                                      6
# 4                                      0
# ..                                   ...
# 264                                   10
# 265                                    3
# 266                                    0
# 267                                   10
# 268                                    3
#
#      What is the Pin Code of where you shop online from?  \
# 0                                                    1
# 1                                                    5
# 2                                                   23
# 3                                                   11
# 4                                                   31
# ..                                                 ...
# 264                                                 13
# ...

# %% [markdown]
# # Removing Outliers:

# %% [markdown]
# # Z-Score Technique:

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(cust))
z.shape
# Out:
# (269, 69)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  4,  16,  20,  30,  35,  49,  79,  88,  95, 112, 116, 133, 142,
#        159, 162, 196, 207, 234, 237, 262], dtype=int64), array([9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9],
#       dtype=int64))

# %%
cust_new=cust[(z<3).all(axis=1)]
print(cust.shape)
print(cust_new.shape)
# Out:
# (269, 69)
# (249, 69)

# %% [markdown]
# Percentage Data Loss:

# %%
loss_percent=(269-249)/269*100
print(loss_percent)
# Out:
# 7.434944237918216

# %% [markdown]
# # IQR Technique:

# %%
q1=cust.quantile(0.25)
q3=cust.quantile(0.75)

IQR=q3-q1
print(IQR)
# Out:
# Which city do you shop online from?                                      5.0
# What is the Pin Code of where you shop online from?                     14.0
# Since How Long You are Shopping Online ?                                 2.0
# How many times you have made an online purchase in the past  year?       3.0
# How do you access the internet while shopping on-line?                   1.0
#                                                                         ...
# Longer delivery period                                                   3.0
# Change in website/Application design                                     5.0
# Frequent disruption when moving from one page to another                 5.0
# Website is as efficient as before                                        4.0
# Which of the Indian online retailer would you recommend to a friend?     5.0
# Length: 69, dtype: float64

# %%
cust_new1=cust[~((cust_en<(q1-1.5*IQR)) | (cust>(q3+1.5*IQR))).any(axis=1)]
print(cust.shape)
print(cust_new1.shape)
# Out:
# (269, 69)
# (112, 69)

# %% [markdown]
# Percentage Data Loss:

# %%
loss_percent=(269-112)/269*100
print(loss_percent)
# Out:
# 58.36431226765799

# %% [markdown]
# The percentage loss in the IQR is more. So we prefer z-score over IQR

# %% [markdown]
# # Dividing data into features and target:

# %%
x=cust_new.iloc[:,:-1]
y=cust_new.iloc[:,-1]

# %%
y.value_counts()
# Out:
# 0    74
# 1    62
# 6    39
# 5    20
# 2    15
# 3    15
# 4    13
# 7    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
xtrain,ytrain=sm.fit_resample(x,y)

# %%
ytrain.value_counts()
# Out:
# 0    74
# 1    74
# 2    74
# 3    74
# 4    74
# 5    74
# 6    74
# 7    74
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %% [markdown]
# # Skewness:

# %%
cust_en.skew()
# Out:
# Gender of respondent                                                    0.741028
# How old are you?                                                        0.680987
# Which city do you shop online from?                                     0.313729
# What is the Pin Code of where you shop online from?                     0.114537
# Since How Long You are Shopping Online ?                               -0.276968
#                                                                           ...
# Longer delivery period                                                 -0.147702
# Change in website/Application design                                    0.354163
# Frequent disruption when moving from one page to another               -0.100608
# Website is as efficient as before                                       0.662084
# Which of the Indian online retailer would you recommend to a friend?    0.583614
# Length: 71, dtype: float64

# %% [markdown]
# Transforming data to remove skewness:

# %%
from sklearn.preprocessing import power_transform
xtrain=power_transform(xtrain,method='yeo-johnson')
xtrain
# Out:
# array([[-0.70161472, -1.79359399,  0.64179798, ..., -0.22815265,
#         -1.78816051, -1.14626859],
#        [-0.70161472, -1.19377453,  0.64179798, ..., -1.38542413,
#          0.01294049, -0.17756044],
#        [ 0.08011045,  0.64267523, -0.33053459, ...,  1.0402093 ,
#          0.93341184, -1.14626859],
#        ...,
#        [ 1.45051713,  0.46778599, -0.33053459, ...,  0.65125005,
#          0.01294049,  1.45981806],
#        [ 1.45051713,  0.64267523,  0.64179798, ...,  0.65125005,
#          0.01294049,  1.45981806],
#        [-0.70161472, -1.79359399,  0.64179798, ...,  0.65125005,
#          0.01294049,  1.45981806]])

# %% [markdown]
# # Scaling:

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtrain
# Out:
# array([[-0.70161472, -1.79359399,  0.64179798, ..., -0.22815265,
#         -1.78816051, -1.14626859],
#        [-0.70161472, -1.19377453,  0.64179798, ..., -1.38542413,
#          0.01294049, -0.17756044],
#        [ 0.08011045,  0.64267523, -0.33053459, ...,  1.0402093 ,
#          0.93341184, -1.14626859],
#        ...,
#        [ 1.45051713,  0.46778599, -0.33053459, ...,  0.65125005,
#          0.01294049,  1.45981806],
#        [ 1.45051713,  0.64267523,  0.64179798, ...,  0.65125005,
#          0.01294049,  1.45981806],
#        [-0.70161472, -1.79359399,  0.64179798, ...,  0.65125005,
#          0.01294049,  1.45981806]])

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %% [markdown]
# # Logistic Regression:

# %%
for i in range(0,1000):
    train_x,test_x,train_y,test_y=train_test_split(xtrain,ytrain,test_size=0.20,random_state=i)
    lg.fit(train_x,train_y)
    pred_train=lg.predict(train_x)
    pred_test=lg.predict(test_x)
    if round(accuracy_score(train_y,pred_train)*100,1)==round(accuracy_score(test_y,pred_test)*100,1):
        print("At random state",i,"The model performs well")
        print("At random state:",i)
        print("Training Accuracy:",accuracy_score(train_y,pred_train)*100)
        print("Testing Accuracy:",accuracy_score(test_y,pred_test)*100)
# Out:
# At random state 0 The model performs well
# At random state: 0
# Training Accuracy: 100.0
# Testing Accuracy: 100.0
# At random state 1 The model performs well
# At random state: 1
# Training Accuracy: 100.0
# Testing Accuracy: 100.0
# At random state 2 The model performs well
# At random state: 2
# Training Accuracy: 100.0
# Testing Accuracy: 100.0
# At random state 3 The model performs well
# At random state: 3
# Training Accuracy: 100.0
# Testing Accuracy: 100.0
# At random state 4 The model performs well
# At random state: 4
# Training Accuracy: 100.0
# Testing Accuracy: 100.0
# At random state 5 The model performs well
# At random state: 5
# Training Accuracy: 100.0
# Testing Accuracy: 100.0
# At random state 6 The model performs well
# At random state: 6
# Training Accuracy: 100.0
# Testing Accuracy: 100.0
# At random state 7 The model performs well
# At random state: 7
# Training Accuracy: 100.0
# Testing Accuracy: 100.0
# At random state 8 The model performs well
# ...

# %%
train_x,test_x,train_y,test_y=train_test_split(xtrain,ytrain,test_size=0.20,random_state=10)
print("Classification Report:",classification_report(test_y,pred_test))
print("Confusion Matrix:",confusion_matrix(test_y,pred_test))
# Out:
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        11
#            1       0.20      0.24      0.22        17
#            2       0.15      0.13      0.14        15
#            3       0.07      0.08      0.07        13
#            4       0.23      0.15      0.18        20
#            5       0.20      0.14      0.17        21
#            6       0.17      0.17      0.17        12
#            7       0.07      0.10      0.08        10
#
#     accuracy                           0.13       119
#    macro avg       0.14      0.13      0.13       119
# weighted avg       0.15      0.13      0.14       119
#
# Confusion Matrix: [[0 1 3 1 1 3 1 1]
#  [3 4 4 1 2 0 1 2]
#  [2 4 2 2 2 2 0 1]
#  [3 1 0 1 3 1 2 2]
#  [3 3 1 3 3 1 2 4]
#  [3 2 2 5 2 3 2 2]
#  [2 3 0 1 0 2 2 2]
#  [1 2 1 0 0 3 2 1]]

# %% [markdown]
# Cross validation score for Logistic Regression:

# %%
from sklearn.model_selection import cross_val_score

lg.fit(train_x,train_y)
lg.score(train_x,train_y)
pred_lg = lg.predict(test_x)

lss = accuracy_score(test_y,pred_lg)
for j in range(2,10):
    lsscore = cross_val_score(lg,xtrain,ytrain,cv=j)
    ls_cv = lsscore.mean() 
    print("At cv:-",j)
    print("Cross validation score is:-",ls_cv*100 )
    print("Accuracy score is :-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 100.0
# Accuracy score is :- 100.0
#
#
# At cv:- 3
# Cross validation score is:- 100.0
# Accuracy score is :- 100.0
#
#
# At cv:- 4
# Cross validation score is:- 100.0
# Accuracy score is :- 100.0
#
#
# At cv:- 5
# Cross validation score is:- 100.0
# Accuracy score is :- 100.0
#
#
# At cv:- 6
# Cross validation score is:- 100.0
# Accuracy score is :- 100.0
#
#
# At cv:- 7
# Cross validation score is:- 100.0
# Accuracy score is :- 100.0
#
#
# At cv:- 8
# Cross validation score is:- 100.0
# Accuracy score is :- 100.0
#
#
# At cv:- 9
# Cross validation score is:- 100.0
# Accuracy score is :- 100.0

# %%
print("At cv:",2)
print("Cross validation score is:",100.0)
print("Accuracy score is :",100.0)
# Out:
# At cv: 2
# Cross validation score is: 100.0
# Accuracy score is : 100.0

# %% [markdown]
# # Decision Tree Classifier:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# %%
parameters = {'criterion':['gini', 'entropy'],'splitter':['best','random']}
dtc = DecisionTreeClassifier()
clf = GridSearchCV(dtc,parameters)
clf.fit(train_x,train_y)

print(clf.best_params_)
# Out:
# {'criterion': 'entropy', 'splitter': 'best'}

# %%
dtc = DecisionTreeClassifier(criterion='gini', splitter='best')
dtc.fit(train_x,train_y)
dtc.score(train_x,train_y)
pred_dtc = dtc.predict(test_x)

print("Accuracy Score:",accuracy_score(test_y,pred_dtc)*100)
print("Classification report:",classification_report(test_y,pred_dtc)*100)
print("Confusion Matrix:",confusion_matrix(test_y,pred_dtc)*100)

dtc_score = cross_val_score(dtc,xtrain,ytrain,cv=2)
dtc_cc = dtc_score.mean() 
print('Cross Val Score:',dtc_cc*100)
# Out:
# Accuracy Score: 100.0
# Classification report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        17
#            2       1.00      1.00      1.00        15
#            3       1.00      1.00      1.00        13
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        21
#            6       1.00      1.00      1.00        12
#            7       1.00      1.00      1.00        10
#
#     accuracy                           1.00       119
#    macro avg       1.00      1.00      1.00       119
# weighted avg       1.00      1.00      1.00       119
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        17
#            2       1.00      1.00      1.00        15
# ...

# %% [markdown]
# # Random Forest Classifier:

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
parameters = {'criterion':['gini', 'entropy'],'n_estimators':[100]}
rfc = RandomForestClassifier()
clf = GridSearchCV(rfc,parameters)
clf.fit(train_x,train_y)

print(clf.best_params_)
# Out:
# {'criterion': 'gini', 'n_estimators': 100}

# %%
rfc = RandomForestClassifier(criterion='gini', n_estimators=100)
rfc.fit(train_x,train_y)
rfc.score(train_x,train_y)
pred_rfc = rfc.predict(test_x)

print("Accuracy Score:",accuracy_score(test_y,pred_rfc)*100)
print("Classification report:",classification_report(test_y,pred_rfc)*100)
print("Confusion Matrix:",confusion_matrix(test_y,pred_rfc)*100)

rfc_score = cross_val_score(rfc,xtrain,ytrain,cv=2)
rfc_cc = rfc_score.mean() 
print('Cross Val Score:',rfc_cc*100)
# Out:
# Accuracy Score: 100.0
# Classification report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        17
#            2       1.00      1.00      1.00        15
#            3       1.00      1.00      1.00        13
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        21
#            6       1.00      1.00      1.00        12
#            7       1.00      1.00      1.00        10
#
#     accuracy                           1.00       119
#    macro avg       1.00      1.00      1.00       119
# weighted avg       1.00      1.00      1.00       119
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        17
#            2       1.00      1.00      1.00        15
# ...

# %% [markdown]
# # Model Saving:

# %%
import pickle
filename='customer_retention.pkl'
pickle.dump(rfc,open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a=np.array(test_y)
predicted=np.array(rfc.predict(test_x))
customer_con=pd.DataFrame({"original":a,"predicted":predicted},index=range(len(a)))
customer_con
# Out:
#      original  predicted
# 0           7          7
# 1           0          0
# 2           4          4
# 3           4          4
# 4           6          6
# ..        ...        ...
# 114         1          1
# 115         3          3
# 116         7          7
# 117         1          1
# 118         5          5
#
# [119 rows x 2 columns]

# %% [markdown]
# # All the models gives the best accuracy. Random Forest Classifier is chosen to save the model.

# %% [markdown]
# From the above report we can see that Amazon.in is most used, liked and recommended by most of the online customers followed by Flipkart.com.
